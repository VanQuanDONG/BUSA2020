# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv('NSBUSA.csv')

# %%
data.drop([0,1],axis = 'index')
data.reset_index(drop = True)
data_cl = data.dropna(axis = 'columns', how = 'all')
data_cl.columns 
a = data.loc[2]
data_cl
#data_cl.rename(columns = {a:data_cl.columns}, inplace= True)
data_cl= data_cl.drop(labels = 0, axis = 0)
data_cl = data_cl.drop(labels = 1, axis = 0)
data_cl = data_cl.reset_index()
data_cl
data_cl.drop(data_cl.columns[[0,1,2]], axis=1) 
a = data_cl.drop(data_cl.columns[[0,1,2]], axis=1) 
a.columns = a.loc[0]
a
a.columns.isna().tolist()

a.isna()
b= a.columns
data
# Out:
#    Unnamed: 0  Non Strata Dwellings               Unnamed: 2  \
# 0         NaN                   NaN                    Local
# 1        Code                   NaN               Government
# 2         NaN                   NaN             Area/Ring/SA
# 3           0                   NaN           Greater Sydney
# 4           1                   NaN               Inner Ring
# ..        ...                   ...                      ...
# 57       6900                  50.0             Shellharbour
# 58       8450                  51.0               Wollongong
# 59          1                   NaN                      GMR
# 60          1                   NaN  Rest of New South Wales
# 61          1                   NaN          NEW SOUTH WALES
#
#                                            Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0               Median Sale Prices ($'000) by Quarter        NaN        NaN
# 1   notes: (s) 30 or less sales contracted;  (-) 1...        NaN        NaN
# 2                                              Mar-91        NaN     Jun-91
# 3                                                 151                   155
# 4                                                 155                   210
# ..                                                ...        ...        ...
# 57                                                  -                   114
# 58                                                  -                   127
# 59                                                132                   143
# 60                                                 95                    98
# 61                                                112                   129
#
#    Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  ... Unnamed: 244 Unnamed: 245  \
# 0         NaN        NaN        NaN        NaN  ...          NaN          NaN
# 1         NaN        NaN        NaN        NaN  ...          NaN          NaN
# 2         NaN     Sep-91        NaN     Dec-91  ...          NaN          NaN
# 3                    160                   173  ...          NaN          NaN
# 4                    215                   245  ...          NaN          NaN
# ..        ...        ...        ...        ...  ...          ...          ...
# 57                   117                   115  ...          NaN          NaN
# 58                   127                   131  ...          NaN          NaN
# 59                   148                   155  ...          NaN          NaN
# 60                    95                    95  ...          NaN          NaN
# 61                   133                   132  ...          NaN          NaN
#
#    Unnamed: 246 Unnamed: 247 Unnamed: 248 Unnamed: 249 Unnamed: 250  \
# 0           NaN          NaN          NaN          NaN          NaN
# 1           NaN          NaN          NaN          NaN          NaN
# 2           NaN          NaN          NaN          NaN          NaN
# 3           NaN          NaN          NaN          NaN          NaN
# 4           NaN          NaN          NaN          NaN          NaN
# ..          ...          ...          ...          ...          ...
# 57          NaN          NaN          NaN          NaN          NaN
# 58          NaN          NaN          NaN          NaN          NaN
# 59          NaN          NaN          NaN          NaN          NaN
# 60          NaN          NaN          NaN          NaN          NaN
# 61          NaN          NaN          NaN          NaN          NaN
#
#    Unnamed: 251 Unnamed: 252 Unnamed: 253
# 0           NaN          NaN          NaN
# 1           NaN          NaN          NaN
# 2           NaN          NaN          NaN
# 3           NaN          NaN          NaN
# 4           NaN          NaN          NaN
# ..          ...          ...          ...
# 57          NaN          NaN          NaN
# 58          NaN          NaN          NaN
# 59          NaN          NaN          NaN
# 60          NaN          NaN          NaN
# 61          NaN          NaN          NaN
#
# [62 rows x 254 columns]

# %%
 c = a.columns.tolist()
c
c
for i in c:
    print(i)
    if type(i) is not str:
        c.remove(i)
# Out:
# Area/Ring/SA
# Mar-91
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# s
# Jun-93
# s
# Sep-93
# s
# Dec-93
# s
# Mar-94
# s
# Jun-94
# s
# Sep-94
# s
# Dec-94
# s
# Mar-95
# s
# Jun-95
# s
# Sep-95
# s
# Dec-95
# s
# Mar-96
# s
# Jun-96
# s
# Sep-96
# s
# Dec-96
# s
# Mar-97
# s
# Jun-97
# s
# Sep-97
# s
# Dec-97
# s
# Mar-98
# s
# Jun-98
# s
# Sep-98
# s
# Dec-98
# s
# Mar-99
# s
# Jun-99
# s
# Sep-99
# s
# Dec-99
# s
# Mar-00
# s
# Jun-00
# s
# Sep-00
# s
# Dec-00
# s
# Mar-01
# s
# Jun-01
# s
# Sep-01
# s
# Dec-01
# s
# Mar-02
# s
# Jun-02
# s
# Sep-02
# s
# Dec-02
# s
# Mar-03
# s
# Jun-03
# s
# Sep-03
# s
# Dec-03
# s
# Mar-04
# s
# Jun-04
# s
# Sep-04
# s
# Dec-04
# s
# Mar-05
# s
# Jun-05
# s
# Sep-05
# s
# Dec-05
# s
# Mar-06
# s
# Jun-06
# s
# Sep-06
# s
# Dec-06
# s
# Mar-07
# s
# Jun-07
# s
# Sep-07
# s
# Dec-07
# s
# Mar-08
# s
# Jun-08
# s
# Sep-08
# s
# Dec-08
# s
# Mar-09
# s
# Jun-09
# s
# Sep-09
# s
# Dec-09
# s
# Mar-10
# s
# Jun-10
# s
# Sep-10
# s
# Dec-10
# s
# Mar-11
# s
# Jun-11
# s
# Sep-11
# s
# Dec-11
# s
# Mar-12
# s
# Jun-12
# s
# Sep-12
# s
# Dec-12
# s
# Mar-13
# s
# Jun-13
# s
# Sep-13
# s
# Dec-13
# s
# Mar-14
# s
# Jun-14
# s
# Sep-14
# s
# Dec-14
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan

# %%
c
# Out:
# ['Area/Ring/SA',
#  'Mar-91',
#  'Jun-91',
#  'Sep-91',
#  'Dec-91',
#  'Mar-92',
#  'Jun-92',
#  'Sep-92',
#  'Dec-92',
#  'Mar-93',
#  's',
#  'Jun-93',
#  's',
#  'Sep-93',
#  's',
#  'Dec-93',
#  's',
#  'Mar-94',
#  's',
#  'Jun-94',
#  's',
#  'Sep-94',
#  's',
#  'Dec-94',
#  's',
#  'Mar-95',
#  's',
#  'Jun-95',
#  's',
#  'Sep-95',
#  's',
#  'Dec-95',
#  's',
#  'Mar-96',
#  's',
#  'Jun-96',
#  's',
#  'Sep-96',
#  's',
#  'Dec-96',
#  's',
#  'Mar-97',
#  's',
#  'Jun-97',
#  's',
#  'Sep-97',
#  's',
#  'Dec-97',
#  's',
#  'Mar-98',
#  's',
#  'Jun-98',
#  's',
#  'Sep-98',
#  's',
#  'Dec-98',
#  's',
#  'Mar-99',
#  's',
#  'Jun-99',
#  's',
#  'Sep-99',
#  's',
#  'Dec-99',
#  's',
#  'Mar-00',
#  's',
#  'Jun-00',
#  's',
#  'Sep-00',
#  's',
#  'Dec-00',
#  's',
#  'Mar-01',
#  's',
#  'Jun-01',
#  's',
#  'Sep-01',
#  's',
#  'Dec-01',
#  's',
#  'Mar-02',
#  's',
#  'Jun-02',
#  's',
#  'Sep-02',
#  's',
#  'Dec-02',
#  's',
#  'Mar-03',
#  's',
#  'Jun-03',
#  's',
#  'Sep-03',
#  's',
#  'Dec-03',
#  's',
#  'Mar-04',
#  's',
#  'Jun-04',
#  's',
#  'Sep-04',
#  's',
#  'Dec-04',
#  's',
#  'Mar-05',
#  's',
#  'Jun-05',
#  's',
#  'Sep-05',
#  's',
#  'Dec-05',
#  's',
#  'Mar-06',
#  's',
#  'Jun-06',
#  's',
#  'Sep-06',
#  's',
#  'Dec-06',
#  's',
#  'Mar-07',
#  's',
#  'Jun-07',
#  's',
#  'Sep-07',
#  's',
#  'Dec-07',
#  's',
#  'Mar-08',
#  's',
#  'Jun-08',
#  's',
#  'Sep-08',
#  's',
#  'Dec-08',
#  's',
#  'Mar-09',
#  's',
#  'Jun-09',
#  's',
#  'Sep-09',
#  's',
#  'Dec-09',
#  's',
#  'Mar-10',
#  's',
#  'Jun-10',
#  's',
#  'Sep-10',
#  's',
#  'Dec-10',
#  's',
#  'Mar-11',
#  's',
#  'Jun-11',
#  's',
#  'Sep-11',
#  's',
#  'Dec-11',
#  's',
#  'Mar-12',
#  's',
#  'Jun-12',
#  's',
#  'Sep-12',
#  's',
#  'Dec-12',
#  's',
#  'Mar-13',
#  's',
#  'Jun-13',
#  's',
#  'Sep-13',
#  's',
#  'Dec-13',
#  's',
#  'Mar-14',
#  's',
#  'Jun-14',
#  's',
#  'Sep-14',
#  's',
#  'Dec-14',
#  'Mar-15',
#  'Jun-15',
#  'Sep-15',
#  'Dec-15',
#  'Mar-16',
#  'Jun-16',
#  'Sep-16',
#  'Dec-16',
#  'Mar-17']

# %%
list = [col for col in c if col.startswith('Jun')]
list.insert(0,'Area/Ring/SA')

# %%
datans_clean = a[list]

# %%
datans_clean
# Out:
# 0              Area/Ring/SA  Jun-91  Jun-92  Jun-93  Jun-94  Jun-95  Jun-96  \
# 0              Area/Ring/SA  Jun-91  Jun-92  Jun-93  Jun-94  Jun-95  Jun-96
# 1            Greater Sydney     155     175     177     184     198     210
# 2                Inner Ring     210     256     254     280     291     315
# 3                  Ashfield     211       -     215     239     217     248
# 4                Botany Bay     185     187     191     234     211     245
# 5                 Lane Cove       -     331     338     386     393     400
# 6                Leichhardt     195     210     215     249     250     265
# 7              Marrickville     128       -     170     190     195     210
# 8                    Mosman     258     538     598     630     660     675
# 9              North Sydney       -     348     362       -     399     450
# 10                 Randwick     239     265     275     322     331     371
# 11                   Sydney     164     179     210     220     245     263
# 12                 Waverley     307     315     301     376     360     400
# 13                Woollahra     460     515     393     550     575     614
# 14              Middle Ring     165     180     198     220     233     242
# 15                   Auburn     130     139     140     155     155     173
# 16                Bankstown     154     160     164     175     181     185
# 17                  Burwood       -       -     228     288     244     265
# 18               Canterbury     140     165     175     185     206     210
# 19               Canada Bay     210       -     245     280     274     308
# 20             Hunters Hill       -     395     400     456     475     385
# 21               Hurstville     185     191     205     225     233     245
# 22                  Kogarah     195     246     250     255     286     317
# 23              Ku-ring-gai       -     350     400     417     420     418
# 24                    Manly     280     295     320     347     383     390
# 25               Parramatta     150     159     160     170     177     172
# 26                 Rockdale     175     186     195     214     213     238
# 27                     Ryde     175     220     235     250     270     257
# 28              Strathfield     220       -     315     320     345     371
# 29               Willoughby       -       -       -       -     379     400
# 30               Outer Ring     136     150     141     143     160     168
# 31          The Hills Shire     230     235     240     246     247     257
# 32                Blacktown     122     123     124     129     129     135
# 33           Blue Mountains     125     127     130     136     144     142
# 34                   Camden     119       -     130     140     147     158
# 35             Campbelltown     104     115     122     125     127     127
# 36                Fairfield     132       -       -       -     145     148
# 37                  Gosford     135     143     144     153     156     163
# 38               Hawkesbury     129     136     133     142     140     154
# 39                  Holroyd     140       -       -       -     162     157
# 40                  Hornsby     240     237     236     258     249     255
# 41                Liverpool      92     135     130     134     153     156
# 42                  Penrith     119     125     125     129     134     134
# 43                Pittwater       -       -       -       -     326     350
# 44               Sutherland     205     218     230       -     250     256
# 45                Warringah       -     245     256       -     285     298
# 46              Wollondilly       -       -     122     123     134     155
# 47                    Wyong     116     120     120     125     130     130
# 48              Rest of GMR     110     114     120     122     130     130
# 49                 Cessnock      73      75      79      80      80      79
# 50                    Kiama     150     168     165     184     181     180
# 51           Lake Macquarie     115     119     124     127     128     129
# 52                 Maitland      95     110     110     108     115     114
# 53                Newcastle     105     110     120     121     123     125
# 54            Port Stephens     130     120       -       -     140     140
# 55             Shellharbour     114     120     124     129     130     135
# 56               Wollongong     127       -       -       -     155     155
# 57                      GMR     143     160     165     172     180     192
# 58  Rest of New South Wales      98      97     102     108     115     116
# 59          NEW SOUTH WALES     129     135     140     148     158     167
#
# 0   Jun-97  Jun-98  Jun-99  ...  Jun-07  Jun-08  Jun-09  Jun-10  Jun-11  \
# 0   Jun-97  Jun-98  Jun-99  ...  Jun-07  Jun-08  Jun-09  Jun-10  Jun-11
# 1      230     250     275  ...     500     499     485     595     600
# 2      375     421     441  ...     895     880     876   1,110   1,120
# 3      300     336     380  ...     772     683     820     858     880
# 4      290     344     350  ...     603     650     664     831     817
# 5      473     551     596  ...   1,104   1,210   1,166   1,410   1,313
# 6      349     380     394  ...     780     788     800     952   1,025
# 7      250     285     313  ...     600     637     640     765     800
# 8      815     920     950  ...   2,175   2,288   1,900   2,100   2,600
# 9      515     635     639  ...   1,040   1,325   1,150   1,535   1,600
# 10     425     507     492  ...   1,065   1,068     965   1,338   1,219
# 11     311     340     350  ...     683     705     710     866     883
# 12     530     545     603  ...   1,309   1,465   1,395   1,500   1,660
# 13     788     930   1,001  ...   1,900   1,600   1,728   2,150   2,226
# 14     272     313     350  ...     600     625     609     750     775
# 15     190     221     260  ...     465     455     474     570     600
# 16     205     240     257  ...     403     400     448     500     535
# 17     343     322     369  ...     700     719     802     903   1,200
# 18     225     280     300  ...     508     520     509     640     668
# 19     370     390     411  ...     804     888     901   1,100   1,068
# 20     670     684     573  ...   1,400   1,470   1,495   1,400   1,668
# 21     248     308     335  ...     557     580     587     710     752
# 22     336     391     431  ...     686     750     725     858     930
# 23     481     536     560  ...   1,070   1,060   1,070   1,220   1,220
# 24     550     590     700  ...   1,300   1,385   1,320   1,476   1,410
# 25     196     230     258  ...     445     468     482     531     575
# 26     264     290     331  ...     551     585     575     740     760
# 27     300     341     375  ...     680     730     751     894     887
# 28     418     460     419  ...   1,100     932     955   1,322   1,240
# 29     460     520     545  ...   1,150   1,150   1,178   1,350   1,348
# 30     175     190     212  ...     409     390     400     462     470
# 31     270     319     350  ...     610     585     617     705     680
# 32     138     158     167  ...     340     340     363     395     400
# 33     150     160     180  ...     343     340     335     395     386
# 34     152     182     216  ...     386     385     400     465     453
# 35     129     138     150  ...     300     287     315     338     340
# 36     153     165     180  ...     340     327     366     420     450
# 37     170     186     217  ...     405     380     383     420     440
# 38     150     175     190  ...     368     375     395     409     419
# 39     173     210     235  ...     395     385     430     466     476
# 40     285     334     370  ...     615     648     645     770     765
# 41     163     186     212  ...     380     370     400     432     445
# 42     137     145     160  ...     335     327     341     370     376
# 43     388     478     480  ...     903     940     910   1,033   1,055
# 44     285     325     380  ...     612     610     625     728     779
# 45     348     418     435  ...     815     835     810     964     950
# 46     155     165     200  ...     380     360     380     398     433
# 47     135     140     155  ...     305     295     310     331     335
# 48     135     145     152  ...     338     335     338     383     385
# 49      81      88      86  ...     220     244     239     255     260
# 50     185     224     250  ...     458     500     492     580     565
# 51     132     138     148  ...     335     335     340     375     376
# 52     115     120     128  ...     295     312     325     355     360
# 53     125     134     135  ...     330     329     333     380     385
# 54     150     165     174  ...     360     352     340     385     385
# 55     135     142     155  ...     340     335     350     364     399
# 56     162     170     188  ...     389     375     380     440     450
# 57     210     227     248  ...     456     450     440     530     533
# 58     120     126     130  ...     280     280     278     315     315
# 59     178     188     200  ...     385     380     380     443     450
#
# 0   Jun-12  Jun-13  Jun-14  Jun-15  Jun-16
# 0   Jun-12  Jun-13  Jun-14  Jun-15  Jun-16
# 1      593     630     730     870     885
# 2    1,066   1,200   1,370   1,740   1,760
# 3      885     900   1,185   1,546   1,453
# 4      810     866   1,120   1,293   1,450
# 5    1,413   1,442   1,728   2,356   2,000
# 6      908   1,015   1,116   1,458   1,500
# 7      760     850     996   1,288   1,280
# 8    2,050   2,325   2,800   3,400   3,225
# 9    1,533   1,590   1,559   2,250   2,131
# 10   1,198   1,272   1,493   1,793   2,040
# 11     890     960   1,190   1,400   1,603
# 12   1,581   1,680   1,930   2,205   2,693
# 13   1,875   2,350   2,440   3,000   3,615
# 14     750     821   1,000   1,300   1,250
# 15     600     653     773     979     938
# 16     555     600     710     873     865
# 17     893     980   1,310   1,653   1,478
# 18     670     715     850   1,150   1,050
# 19     995   1,157   1,333   1,750   1,790
# 20   1,390   1,558   1,908   2,141   3,200
# 21     731     800   1,000   1,193   1,170
# 22     801     929   1,225   1,423   1,530
# 23   1,130   1,320   1,500   1,920   1,848
# 24   1,475   1,604   1,638   2,000   2,100
# 25     575     650     762   1,000     975
# 26     734     800   1,047   1,236   1,115
# 27     880     921   1,242   1,526   1,538
# 28   1,225   1,286   1,378   1,806   2,000
# 29   1,388   1,450   1,565   2,150   2,240
# 30     480     500     580     694     730
# 31     680     782     929   1,250   1,200
# 32     425     440     530     660     668
# 33     400     410     459     540     584
# 34     475     495     542     646     716
# 35     342     360     432     565     568
# 36     445     490     575     738     745
# 37     415     449     504     625     653
# 38     435     480     535     640     712
# 39     520     541     670     830     801
# 40     745     830     955   1,250   1,250
# 41     455     500     570     716     750
# 42     405     420     492     614     625
# 43     928   1,050   1,165   1,500   1,560
# 44     760     780     900   1,110   1,130
# 45     905     955   1,170   1,400   1,518
# 46     430     470     550     600     703
# 47     335     355     389     455     494
# 48     395     406     445     480     505
# 49     265     280     290     300     321
# 50     560     570     600     730     755
# 51     400     393     433     471     488
# 52     374     370     389     393     430
# 53     390     430     460     499     510
# 54     381     391     430     423     480
# 55     403     390     430     529     564
# 56     450     450     500     599     660
# 57     535     565     650     750     770
# 58     313     319     338     360     379
# 59     440     470     530     595     605
#
# [60 rows x 27 columns]

# %%
datans_clean.to_csv('cleanBUSANS.csv', index = False)
