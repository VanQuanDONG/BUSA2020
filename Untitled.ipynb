# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv('SBUSA.csv')

# %%
data
data.drop([0,1],axis = 'index')
data.reset_index(drop = True)
data_cl = data.dropna(axis = 'columns', how = 'all')
a = data.loc[2]
data_cl
data_cl= data_cl.drop(labels = 0, axis = 0)
data_cl = data_cl.drop(labels = 1, axis = 0)
data_cl = data_cl.reset_index()
data_cl
data_cl.drop(data_cl.columns[[0,1,2]], axis=1) 
a = data_cl.drop(data_cl.columns[[0,1,2]], axis=1) 
a.columns = a.loc[0]
a
a.columns.isna().tolist()

a.isna()
b= a.columns
a
# Out:
# 0              Area/Ring/SA  Mar-91  NaN  Jun-91  NaN  Sep-91  NaN  Dec-91  \
# 0              Area/Ring/SA  Mar-91  NaN  Jun-91  NaN  Sep-91  NaN  Dec-91
# 1            Greater Sydney     135          140          137          148
# 2                Inner Ring     129          130          140          153
# 3                  Ashfield     127          124          128          129
# 4                Botany Bay       -            -          115    s     116
# 5                 Lane Cove       -            -            -          165
# 6                Leichhardt       -            -            -          146
# 7              Marrickville       -            -          104          110
# 8                    Mosman       -            -            -          198
# 9              North Sydney       -            -            -          216
# 10                 Randwick       -            -          165          155
# ...

# %%
 c = a.columns.tolist()
c
c
for i in c:
    print(i)
    if type(i) is not str:
        c.remove(i)
# Out:
# Area/Ring/SA
# Mar-91
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# s
# Jun-93
# s
# Sep-93
# s
# Dec-93
# s
# Mar-94
# s
# Jun-94
# s
# Sep-94
# s
# Dec-94
# s
# Mar-95
# s
# Jun-95
# s
# Sep-95
# s
# Dec-95
# s
# Mar-96
# s
# Jun-96
# s
# Sep-96
# s
# Dec-96
# s
# Mar-97
# s
# Jun-97
# s
# Sep-97
# s
# Dec-97
# s
# Mar-98
# s
# Jun-98
# s
# Sep-98
# s
# Dec-98
# s
# Mar-99
# s
# Jun-99
# s
# Sep-99
# s
# Dec-99
# s
# Mar-00
# s
# Jun-00
# s
# Sep-00
# s
# Dec-00
# s
# Mar-01
# s
# Jun-01
# s
# Sep-01
# s
# Dec-01
# s
# Mar-02
# s
# Jun-02
# s
# Sep-02
# s
# Dec-02
# s
# Mar-03
# s
# Jun-03
# s
# Sep-03
# s
# Dec-03
# s
# Mar-04
# s
# Jun-04
# s
# Sep-04
# s
# Dec-04
# s
# Mar-05
# s
# Jun-05
# s
# Sep-05
# s
# Dec-05
# s
# Mar-06
# s
# Jun-06
# s
# Sep-06
# s
# Dec-06
# s
# Mar-07
# s
# Jun-07
# s
# Sep-07
# s
# Dec-07
# s
# Mar-08
# s
# Jun-08
# s
# Sep-08
# s
# Dec-08
# s
# Mar-09
# s
# Jun-09
# s
# Sep-09
# s
# Dec-09
# s
# Mar-10
# s
# Jun-10
# s
# Sep-10
# s
# Dec-10
# s
# ...

# %%
list = [col for col in c if col.startswith('Jun')]
list.insert(0,'Area/Ring/SA')

# %%
data_clean = a[list]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [18], in <cell line: 1>()
# ----> 1 data_clean = a[a[list]]
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:3492, in DataFrame.__getitem__(self, key)
#    3490 # Do we have a (boolean) DataFrame?
#    3491 if isinstance(key, DataFrame):
# -> 3492     return self.where(key)
#    3494 # Do we have a (boolean) 1d indexer?
#    3495 if com.is_bool_indexer(key):
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# ...

# %%
data_clean['Area/Ring/SA']
# Out:
# 0                Area/Ring/SA
# 1              Greater Sydney
# 2                  Inner Ring
# 3                    Ashfield
# 4                  Botany Bay
# 5                   Lane Cove
# 6                  Leichhardt
# 7                Marrickville
# 8                      Mosman
# 9                North Sydney
# 10                   Randwick
# 11                     Sydney
# 12                   Waverley
# 13                  Woollahra
# 14                Middle Ring
# 15                     Auburn
# 16                  Bankstown
# 17                    Burwood
# 18                 Canterbury
# 19                 Canada Bay
# 20               Hunters Hill
# 21                 Hurstville
# 22                    Kogarah
# 23                Ku-ring-gai
# 24                      Manly
# 25                 Parramatta
# 26                   Rockdale
# 27                       Ryde
# 28                Strathfield
# 29                 Willoughby
# 30                 Outer Ring
# ...

# %%
a[list]
# Out:
# 0              Area/Ring/SA  Jun-91  Jun-92  Jun-93  Jun-94  Jun-95  Jun-96  \
# 0              Area/Ring/SA  Jun-91  Jun-92  Jun-93  Jun-94  Jun-95  Jun-96
# 1            Greater Sydney     140     148     155     159     173     181
# 2                Inner Ring     130     183     174     185     208     220
# 3                  Ashfield     124       -     127     130     146     150
# 4                Botany Bay       -     132     122     135     135     146
# 5                 Lane Cove       -     165     185     202     175     189
# 6                Leichhardt       -     190     158     181     195     240
# 7              Marrickville       -     117     121     127     120     135
# 8                    Mosman       -     235     215     264     235     252
# 9              North Sydney       -     215     230       -     255     270
# 10                 Randwick       -     164     172     203     199     227
# ...

# %%
data_clean.to_csv('SBUSA2020.csv', index= False)
